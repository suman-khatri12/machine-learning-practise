# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
data = pd.read_csv("E://Iris.csv")
data1 = data.copy()

# %%
data.species
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
data['species'] = data['species'].map({"setosa":0, "virginica":1, "versicolor":2})

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        1
# 146           6.3          2.5           5.0          1.9        1
# 147           6.5          3.0           5.2          2.0        1
# 148           6.2          3.4           5.4          2.3        1
# 149           5.9          3.0           5.1          1.8        1
#
# [150 rows x 5 columns]

# %%
sns.lineplot(x = data.sepal_length, y = data.sepal_width, hue=data1.species)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.histplot(x = data.sepal_length, y = data.sepal_width, hue = data.species, kde = True)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
data['species'].value_counts()
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %% [markdown]
# ## Scatterplot

# %%
plt.scatter(x = data.sepal_length, y=data.sepal_width)
plt.xlabel = "Sepal Length"
plt.ylabel = "Sepal Width"
plt.show()

# %%
sns.scatterplot(x = data.sepal_length, y = data.sepal_width, hue = data.species)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.jointplot(x = data.sepal_length, y = data.sepal_width)

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = data.sepal_length, y = data.sepal_width, hue= data.species, palette = "Set1")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.boxplot(x = data.species, y = data.petal_length)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
colors = ('red', 'green', 'black')

# %%
def size(m, n):
    plt.figure(figsize = (m , n))

# %%
size(10, 10)
ax = sns.boxplot(x = data.species , y = data.petal_length)
ax = sns.stripplot(x = data.species, y = data.petal_length, palette= colors)

# %%
size(10, 10)
sns.violinplot(x = data.species, y = data.petal_length)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %% [markdown]
# ### using kdeplot for univariate relationship

# %%
size(10, 10)
ax = sns.kdeplot(x = data['petal_length'] , hue = data.species, palette= colors)
ax = sns.kdeplot(x = data.petal_width , hue= data.species, palette= 'Set3')

# %%
sns.pairplot(data[['petal_length']], hue =data.species)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-3a940dea3369> in <module>
# ----> 1 sns.pairplot(data[['petal_length']], hue =data.species)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    1989     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    1990                     hue_order=hue_order, palette=palette, corner=corner,
# ...

# %%
data.boxplot(by='species', figsize = (12, 10))
plt.show()

# %%
from pandas.plotting import andrews_curves, parallel_coordinates, radviz
andrews_curves(data, 'species')
# Out:
# <AxesSubplot:>

# %%
parallel_coordinates(data, 'species')
# Out:
# <AxesSubplot:>

# %%
radviz(data, 'species')
# Out:
# <AxesSubplot:>
