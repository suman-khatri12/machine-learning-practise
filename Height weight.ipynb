# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.figure_factory as ff
sns.set()

# %%
data = pd.read_csv("E:\\height_weight.csv")

# %%
data.head(10)
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3
# 5    Male     189     104      3
# 6    Male     147      92      5
# 7    Male     154     111      5
# 8    Male     174      90      3
# 9  Female     169     103      4

# %%
data1 = data.copy()

# %%
from sklearn.impute import SimpleImputer

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
label.fit(data["Gender"])
data1['Gender'] = label.transform(data["Gender"])
data1
# Out:
#      Gender  Height  Weight  Index
# 0         1     174      96      4
# 1         1     189      87      2
# 2         0     185     110      4
# 3         0     195     104      3
# 4         1     149      61      3
# ..      ...     ...     ...    ...
# 495       0     150     153      5
# 496       0     184     121      4
# 497       0     141     136      5
# 498       1     150      95      5
# 499       1     173     131      5
#
# [500 rows x 4 columns]

# %%
asaa = label.inverse_transform(data1["Gender"])

# %%
data
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
sns.distplot(data.Height, color= 'red')

# %%
sns.distplot(data.Index, color= 'green')

# %%
plt.figure(figsize= (8,8))
sns.scatterplot(data.Height, data.Weight, hue = data.Index, palette='Set1')

# %%
data.describe()
# Out:
#            Height      Weight       Index
# count  500.000000  500.000000  500.000000
# mean   169.944000  106.000000    3.748000
# std     16.375261   32.382607    1.355053
# min    140.000000   50.000000    0.000000
# 25%    156.000000   80.000000    3.000000
# 50%    170.500000  106.000000    4.000000
# 75%    184.000000  136.000000    5.000000
# max    199.000000  160.000000    5.000000

# %%
data['Index'].value_counts()
# Out:
# 5    198
# 4    130
# 2     69
# 3     68
# 1     22
# 0     13
# Name: Index, dtype: int64

# %%
data['Gender'].value_counts()
# Out:
# Female    255
# Male      245
# Name: Gender, dtype: int64

# %%
data2 = data.where(data['Gender'] == 'Male')

# %%
data2.dropna(inplace=True)

# %%
data2.reset_index(inplace=True)

# %%
data2.drop(['index'],axis = 0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-565c2f1ef7ab> in <module>
# ----> 1 data2.drop(['index'],axis = 0, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
data2
# Out:
#      index Gender  Height  Weight  Index
# 0        0   Male   174.0    96.0    4.0
# 1        1   Male   189.0    87.0    2.0
# 2        4   Male   149.0    61.0    3.0
# 3        5   Male   189.0   104.0    3.0
# 4        6   Male   147.0    92.0    5.0
# ..     ...    ...     ...     ...    ...
# 240    487   Male   187.0    80.0    2.0
# 241    488   Male   198.0   136.0    4.0
# 242    494   Male   152.0    98.0    5.0
# 243    498   Male   150.0    95.0    5.0
# 244    499   Male   173.0   131.0    5.0
#
# [245 rows x 5 columns]

# %%
data.groupby(data.Gender).groups
# Out:
# {'Female': Int64Index([  2,   3,   9,  11,  12,  15,  16,  21,  22,  24,
#              ...
#              484, 486, 489, 490, 491, 492, 493, 495, 496, 497],
#             dtype='int64', length=255),
#  'Male': Int64Index([  0,   1,   4,   5,   6,   7,   8,  10,  13,  14,
#              ...
#              473, 475, 477, 483, 485, 487, 488, 494, 498, 499],
#             dtype='int64', length=245)}

# %%
sns.scatterplot(y = data["Height"], x = data['Gender'], hue=data['Index'])

# %%
sns.barplot(data["Height"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-f6efd4a7cc69> in <module>
# ----> 1 plt.hist(data['Height'], data['Index'], color=data["Gender"])
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2641         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2642         color=color, label=label, stacked=stacked, normed=normed,
# -> 2643         **({"data": data} if data is not None else {}), **kwargs)
#    2644
#    2645
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
# ...
